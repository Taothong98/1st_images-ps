# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QwmftxjJQUGBcvg4mACZ")
project = rf.workspace("riis").project("aerial-sheep")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Aerial-Sheep-1 in yolov8:: 100%|██████████| 8278/8278 [00:00<00:00, 8564.42it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QwmftxjJQUGBcvg4mACZ")
project = rf.workspace("rf100vltemp").project("aerial-sheep-fsod-qmoz")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to aerial-sheep-fsod-qmoz-1 in yolov11:: 100%|██████████| 848/848 [00:00<00:00, 8004.90it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QwmftxjJQUGBcvg4mACZ")
project = rf.workspace("test-8gntr").project("aerial-sheep-926fa")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to aerial-sheep-2 in yolov11:: 100%|██████████| 89/89 [00:00<00:00, 8722.00it/s]
